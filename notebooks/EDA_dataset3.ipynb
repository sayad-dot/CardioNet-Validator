# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Load dataset 3
df = pd.read_csv('../data/dataset3.csv')  # adjust path if needed

print(df.columns)


# Clean column names
df.columns = df.columns.str.strip()

# Display first 5 rows
print("First 5 rows of dataset 3:")
print(df.head())

# Basic info
print("\nShape of dataset:", df.shape)
print("\nColumns:")
print(df.columns)
print("\nData types:")
print(df.dtypes)
print("\nMissing values:")
print(df.isnull().sum())

# Statistical summary
print("\nStatistical summary:")
print(df.describe())

# Target column name (update as per dataset3)
target_col = 'target'  # Change if your target column has a different name

# Target distribution
print(f"\nValue counts of target column '{target_col}':")
print(df[target_col].value_counts())

sns.countplot(data=df, x=target_col, palette='pastel')
plt.title('Target Class Distribution')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 10))
correlation = df.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# Feature distributions (first 6 numeric features)
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
for col in numerical_cols[:6]:
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Optional: Pairplot (commented out by default)
# sns.pairplot(df[numerical_cols[:5] + [target_col]], hue=target_col)
# plt.show()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')
# First 5 rows of dataset 3:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
#
# Shape of dataset: (303, 14)
#
# Columns:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
# ...
